# %%
import pandas as pd

#Load dataset
data = pd.read_csv("Documents/BU/DSC 350/week 3/data/parsed.csv")
data.head()
# Out:
#   alert  cdi      code                                             detail  \
# 0   NaN  NaN  37389218  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 1   NaN  NaN  37389202  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 2   NaN  4.4  37389194  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 3   NaN  NaN  37389186  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 4   NaN  NaN  73096941  https://earthquake.usgs.gov/fdsnws/event/1/que...
#
#        dmin  felt    gap           ids   mag magType  ...     status  \
# 0  0.008693   NaN   85.0  ,ci37389218,  1.35      ml  ...  automatic
# 1  0.020030   NaN   79.0  ,ci37389202,  1.29      ml  ...  automatic
# 2  0.021370  28.0   21.0  ,ci37389194,  3.42      ml  ...  automatic
# 3  0.026180   NaN   39.0  ,ci37389186,  0.44      ml  ...  automatic
# 4  0.077990   NaN  192.0  ,nc73096941,  2.16      md  ...  automatic
#
#            time                          title tsunami        type  \
# ...

# %%
#Question 1
#Filtering data with appropriate columns
new_data = data.loc[(data.magType == 'mb') & (data.parsed_place == 'Japan')]

new_data.head()
# Out:
#      alert  cdi      code                                             detail  \
# 67     NaN  NaN  1000hbqa  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 713    NaN  NaN  1000hah8  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 1124   NaN  NaN  1000h9la  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 1309   NaN  NaN  1000h952  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 1398   NaN  NaN  1000h8zx  https://earthquake.usgs.gov/fdsnws/event/1/que...
#
#        dmin  felt    gap           ids  mag magType  ...    status  \
# 67    1.415   NaN   72.0  ,us1000hbqa,  4.6      mb  ...  reviewed
# 713   1.141   NaN   82.0  ,us1000hah8,  4.7      mb  ...  reviewed
# 1124  1.737   NaN  135.0  ,us1000h9la,  4.6      mb  ...  reviewed
# 1309  0.897   NaN  136.0  ,us1000h952,  4.5      mb  ...  reviewed
# 1398  0.555   NaN  124.0  ,us1000h8zx,  4.4      mb  ...  reviewed
#
#               time                                    title tsunami  \
# ...

# %%
#Question 2
#Filtering data with appropriate columns
df = data.loc[(data.parsed_place == 'Indonesia') & (data.type == 'earthquake')]
df.head()
# Out:
#      alert  cdi      code                                             detail  \
# 9      NaN  NaN  1000hbtn  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 13     NaN  NaN  1000hbti  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 180  green  NaN  1000hbhw  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 421    NaN  NaN  1000hayw  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 660    NaN  NaN  1000haks  https://earthquake.usgs.gov/fdsnws/event/1/que...
#
#       dmin  felt    gap           ids  mag magType  ...    status  \
# 9    3.191   NaN   37.0  ,us1000hbtn,  4.7      mb  ...  reviewed
# 13   2.193   NaN  157.0  ,us1000hbti,  4.5      mb  ...  reviewed
# 180  2.077   NaN   23.0  ,us1000hbhw,  5.2     mww  ...  reviewed
# 421  2.812   NaN   80.0  ,us1000hayw,  4.7      mb  ...  reviewed
# 660  2.612   NaN   90.0  ,us1000haks,  4.4      mb  ...  reviewed
#
#              time                                        title tsunami  \
# ...

# %%
#count of earthquakes
df['type'].value_counts()
# Out:
# earthquake    147
# Name: type, dtype: int64

# %%
#count of earthquakes followed by tsunamis
df['tsunami'].value_counts()
# Out:
# 0    113
# 1     34
# Name: tsunami, dtype: int64

# %%
#Calculate percentage of earthquakes coupled with tsunamis
per = (34/147)*100
print(per)
# Out:
# 23.12925170068027

# %%
#Question 3
#Filtering data with appropriate columns
nevada = data.loc[(data.parsed_place == 'Nevada') & (data.type == 'earthquake')]

nevada.head()
# Out:
#    alert  cdi    code                                             detail  \
# 32   NaN  NaN  660878  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 39   NaN  NaN  660886  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 41   NaN  NaN  660885  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 48   NaN  NaN  660867  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 49   NaN  NaN  660884  https://earthquake.usgs.gov/fdsnws/event/1/que...
#
#      dmin  felt     gap           ids  mag magType  ...    status  \
# 32  0.091   NaN  155.59  ,nn00660878,  1.3      ml  ...  reviewed
# 39  0.095   NaN  155.25  ,nn00660886, -0.1      ml  ...  reviewed
# 41  0.097   NaN  156.31  ,nn00660885,  0.2      ml  ...  reviewed
# 48  0.326   NaN  111.14  ,nn00660867,  0.9      ml  ...  reviewed
# 49  0.097   NaN  155.98  ,nn00660884, -0.1      ml  ...  reviewed
#
#             time                                     title tsunami  \
# ...

# %%
nevada['type'].value_counts()
# Out:
# earthquake    647
# Name: type, dtype: int64

# %%
#Get summary statistics for eathquakes in Nevada
nevada.describe()
# Out:
#              cdi        dmin       felt         gap         mag   mmi  \
# count  14.000000  647.000000  14.000000  647.000000  647.000000  1.00
# mean    2.421429    0.163155   2.500000  154.436615    0.437311  2.84
# std     0.514675    0.161793   4.783787   69.474945    0.653397   NaN
# min     2.000000    0.001000   1.000000   29.140000   -0.500000  2.84
# 25%     2.000000    0.053000   1.000000   97.295000   -0.100000  2.84
# 50%     2.200000    0.109000   1.000000  150.040000    0.300000  2.84
# 75%     3.000000    0.223000   1.000000  200.515000    0.800000  2.84
# max     3.300000    1.414000  19.000000  355.910000    2.900000  2.84
#
#               nst         rms         sig          time  tsunami     tz  \
# count  647.000000  647.000000  647.000000  6.470000e+02    647.0  647.0
# mean    12.704791    0.140627    9.146832  1.538318e+12      0.0 -480.0
# std     10.052695    0.056765   17.939055  5.955836e+08      0.0    0.0
# ...

# %%
#Question 4
#Filtering data with appropriate columns
earth = data.loc[(data.type == 'earthquake')]
earth.head()
# Out:
#   alert  cdi      code                                             detail  \
# 0   NaN  NaN  37389218  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 1   NaN  NaN  37389202  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 2   NaN  4.4  37389194  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 3   NaN  NaN  37389186  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 4   NaN  NaN  73096941  https://earthquake.usgs.gov/fdsnws/event/1/que...
#
#        dmin  felt    gap           ids   mag magType  ...     status  \
# 0  0.008693   NaN   85.0  ,ci37389218,  1.35      ml  ...  automatic
# 1  0.020030   NaN   79.0  ,ci37389202,  1.29      ml  ...  automatic
# 2  0.021370  28.0   21.0  ,ci37389194,  3.42      ml  ...  automatic
# 3  0.026180   NaN   39.0  ,ci37389186,  0.44      ml  ...  automatic
# 4  0.077990   NaN  192.0  ,nc73096941,  2.16      md  ...  automatic
#
#            time                          title tsunami        type  \
# ...

# %%
earth['type'].value_counts()
# Out:
# earthquake    9081
# Name: type, dtype: int64

# %%
earth.loc[
    earth.parsed_place.isin(['Alaska', 'Washington', 'California']),
]
# Out:
#      alert  cdi      code                                             detail  \
# 0      NaN  NaN  37389218  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 1      NaN  NaN  37389202  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 2      NaN  4.4  37389194  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 3      NaN  NaN  37389186  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 4      NaN  NaN  73096941  https://earthquake.usgs.gov/fdsnws/event/1/que...
# ...    ...  ...       ...                                                ...
# 9326   NaN  NaN  38063975  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 9327   NaN  NaN  73086771  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 9328   NaN  NaN  38063967  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 9330   NaN  NaN  38063959  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 9331   NaN  NaN  38063935  https://earthquake.usgs.gov/fdsnws/event/1/que...
#
# ...

# %%
earth['Country/State'] = 'US State'
earth.head()
# Out:
# C:\Users\12162\AppData\Local\Temp/ipykernel_12144/426617649.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   earth['Country/State'] = 'US State'
#   alert  cdi      code                                             detail  \
# 0   NaN  NaN  37389218  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 1   NaN  NaN  37389202  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 2   NaN  4.4  37389194  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 3   NaN  NaN  37389186  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 4   NaN  NaN  73096941  https://earthquake.usgs.gov/fdsnws/event/1/que...
#
#        dmin  felt    gap           ids   mag magType  ...  \
# 0  0.008693   NaN   85.0  ,ci37389218,  1.35      ml  ...
# ...

# %%
earth.loc[
    earth.parsed_place.isin(['Bolvia', 'Chile', 'Ecador', 'Peru', 'Costa Rica', 'Guatemala', 'Mexico'
                            'Japan', 'Philippines', 'Indonesia', 'New Zealand', 'Antartic', 'Canada', 'Fiji', 'Russia'
                            'Taiwan', 'Tonga', 'Kermadec Islands']),
]
# Out:
#       alert  cdi      code                                             detail  \
# 9       NaN  NaN  1000hbtn  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 13      NaN  NaN  1000hbti  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 15      NaN  NaN  20280430  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 176     NaN  NaN  1000hbig  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 180   green  NaN  1000hbhw  https://earthquake.usgs.gov/fdsnws/event/1/que...
# ...     ...  ...       ...                                                ...
# 9212    NaN  3.1  2000hg94  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 9213    NaN  NaN  2000hg99  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 9282    NaN  NaN  2000hg7v  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 9309    NaN  2.7  2000hg6g  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 9321    NaN  NaN  2000hjsq  https://earthquake.usgs.gov/fdsnws/event/1/que...
#
# ...

# %%
earth['Country/State'] = 'Country'
earth.head()
# Out:
# C:\Users\12162\AppData\Local\Temp/ipykernel_12144/3404924998.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   earth['Country/State'] = 'Country'
#   alert  cdi      code                                             detail  \
# 0   NaN  NaN  37389218  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 1   NaN  NaN  37389202  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 2   NaN  4.4  37389194  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 3   NaN  NaN  37389186  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 4   NaN  NaN  73096941  https://earthquake.usgs.gov/fdsnws/event/1/que...
#
#        dmin  felt    gap           ids   mag magType  ...  \
# 0  0.008693   NaN   85.0  ,ci37389218,  1.35      ml  ...
# ...

# %%
#Question 5

earth = data.loc[(data.parsed_place == 'Alaska')]
earth.head()
# Out:
#    alert  cdi      code                                             detail  \
# 6    NaN  NaN  20280432  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 18   NaN  NaN  20280424  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 21   NaN  NaN  20280421  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 26   NaN  NaN  20280415  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 27   NaN  NaN  20280412  https://earthquake.usgs.gov/fdsnws/event/1/que...
#
#     dmin  felt  gap                      ids  mag magType  ...     status  \
# 6    NaN   NaN  NaN             ,ak20280432,  1.7      ml  ...  automatic
# 18   NaN   NaN  NaN             ,ak20280424,  2.0      ml  ...  automatic
# 21   NaN   NaN  NaN             ,ak20280421,  1.7      ml  ...  automatic
# 26   NaN   NaN  NaN  ,ak20280415,us1000hbta,  2.8      ml  ...  automatic
# 27   NaN   NaN  NaN             ,ak20280412,  1.1      ml  ...  automatic
#
# ...

# %%
earth['parsed_place'].value_counts()
# Out:
# Alaska    3665
# Name: parsed_place, dtype: int64

# %%
earth = data.loc[(data.parsed_place == 'California')]
earth.head()
# Out:
#   alert  cdi      code                                             detail  \
# 0   NaN  NaN  37389218  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 1   NaN  NaN  37389202  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 2   NaN  4.4  37389194  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 3   NaN  NaN  37389186  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 4   NaN  NaN  73096941  https://earthquake.usgs.gov/fdsnws/event/1/que...
#
#        dmin  felt    gap           ids   mag magType  ...     status  \
# 0  0.008693   NaN   85.0  ,ci37389218,  1.35      ml  ...  automatic
# 1  0.020030   NaN   79.0  ,ci37389202,  1.29      ml  ...  automatic
# 2  0.021370  28.0   21.0  ,ci37389194,  3.42      ml  ...  automatic
# 3  0.026180   NaN   39.0  ,ci37389186,  0.44      ml  ...  automatic
# 4  0.077990   NaN  192.0  ,nc73096941,  2.16      md  ...  automatic
#
#            time                          title tsunami        type  \
# ...

# %%
earth['parsed_place'].value_counts()
# Out:
# California    2861
# Name: parsed_place, dtype: int64

# %%
earth = data.loc[(data.parsed_place == 'Washington')]
earth.head()
# Out:
#     alert  cdi      code                                             detail  \
# 134   NaN  NaN  61437386  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 203   NaN  NaN  61437266  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 427   NaN  NaN  61437071  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 498   NaN  NaN  61436971  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 526   NaN  NaN  61436951  https://earthquake.usgs.gov/fdsnws/event/1/que...
#
#         dmin  felt    gap           ids   mag magType  ...    status  \
# 134  0.02240   NaN  101.0  ,uw61437386,  0.72      ml  ...  reviewed
# 203  0.11580   NaN   59.0  ,uw61437266,  1.87      ml  ...  reviewed
# 427  0.01787   NaN  157.0  ,uw61437071,  0.45      ml  ...  reviewed
# 498  0.04412   NaN  110.0  ,uw61436971,  1.50      ml  ...  reviewed
# 526  0.14290   NaN  125.0  ,uw61436951,  1.57      ml  ...  reviewed
#
#              time                                     title tsunami  \
# ...

# %%
earth['parsed_place'].value_counts()
# Out:
# Washington    157
# Name: parsed_place, dtype: int64

# %%
#Question 6

earth = data.loc[(data.parsed_place == 'Bolivia')]
earth.head()

earth['tsunami'].value_counts()
# Out:
# 0    4
# Name: tsunami, dtype: int64

# %%
earth = data.loc[(data.parsed_place == 'Peru')]
earth.head()

earth['tsunami'].value_counts()
# Out:
# 0    14
# Name: tsunami, dtype: int64

# %%
earth = data.loc[(data.parsed_place == 'New Zealand')]
earth.head()

earth['tsunami'].value_counts()
# Out:
# 0    13
# Name: tsunami, dtype: int64

# %%
earth = data.loc[(data.parsed_place == 'Mexico')]
earth.head()

earth['tsunami'].value_counts()
# Out:
# 0    37
# 1     1
# Name: tsunami, dtype: int64
